# %%
import pandas as pd


#WNV_WT Sequence
WT="..."


#upload data file
df=pd.read_csv("More Barcodes From Fitz/CSV Files/cxt_12dpi_mg_all_true_barcodes_without_duplicates.csv", index_col=0)

#now I need to make a list of all the barcode sequences

list = []
WNV_100 = WT[7188:7238]
WNV_200 = WT[7270:7320]
#lets try to make the barcode sequences have the first 50 bases of WT and the second 50 bases of WT
for i in df["Barcode Sequence"]:

    list.append(WNV_100 + i + WNV_200)

#now we have to add it back to the original data set

df["Alligned Barcode"] = list

df.to_csv("Alligned Barcodes-50bp flanks/Input_vs_mg_all_barcodes_133bp_Alligned.csv")
df.to_pickle("Alligned Barcodes-50bp flanks/Input_vs_mg_all_barcodes_133bp_Alligned.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d49b10f33f66> in <module>
#      23 df["Alligned Barcode"] = list
#      24
# ---> 25 df.to_csv("Alligned Barcodes-50bp flanks/Input_vs_mg_all_barcodes_133bp_Alligned.csv")
#      26 df.to_pickle("Alligned Barcodes-50bp flanks/Input_vs_mg_all_barcodes_133bp_Alligned.pkl")
#
# /curc/sw/anaconda3/2020.11/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# /curc/sw/anaconda3/2020.11/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
# ...
